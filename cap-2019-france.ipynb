# %% [markdown]
# ## Qui sont les bénéficiaires de la Politique agricole commune en France ? Données 2018-2019
#
# Cette analyse de données reprend le canevas utilisé pour l'analyse des bénéficiaires de la Politique agricole commune en Pologne au cours des années [2018](https://github.com/echapelier/eu-agri-subsidies/blob/master/cap-2018-poland.ipynb) et [2019](https://github.com/echapelier/eu-agri-subsidies/blob/master/cap-2019-poland.ipynb). À la différence de la pratique en Pologne, les [données publiées par les autorités françaises](https://www.telepac.agriculture.gouv.fr/telepac/tbp/accueil/accueil.action) ne sont pas découpées en années calendaires mais en campagnes de paiement qui s'étendent d'octobre à octobre de l'année suivante. Nous allons analyser la campagne 2018-2019, qui s'était étendue du 16 octobre 2018 au 15 octobre 2019 et dont les données ont été publiées au printemps 2020.
#
# Avant de générer un dataframe à partir du fichier CSV fourni par l'agence de paiement, nous allons en tirer un aperçu à l'aide de commandes shell.

# %%
# !head cap-2019-france.csv
# Out:
# Nom / Raison sociale; Commune; Code postal; Libell� rubrique; Montant rubrique
# XXX;XXX;01XXX;III.7 - Aide dans le secteur de l'apiculture;460,00
# XXX;XXX;01XXX;III.7 - Aide dans le secteur de l'apiculture;796,00
# XXX;XXX;01XXX;III.7 - Aide dans le secteur de l'apiculture;1000,00
# XXX;XXX;01XXX;II.1 - Aide de base d�coupl�e � la surface (DPB);246,83
# XXX;XXX;01XXX;II.1 - Aide de base d�coupl�e � la surface (DPB);467,72
# XXX;XXX;01XXX;II.1 - Aide de base d�coupl�e � la surface (DPB);222,65
# XXX;XXX;01XXX;II.1 - Aide de base d�coupl�e � la surface (DPB);535,70
# XXX;XXX;01XXX;II.1 - Aide de base d�coupl�e � la surface (DPB);232,10
# XXX;XXX;01XXX;II.1 - Aide de base d�coupl�e � la surface (DPB);407,21

# %%
# Problème d'encodage, conversion des données en UTF-8
# !iconv -f ISO-8859-1 -t UTF-8 cap-2019-france.csv > cap-2019-france-utf8.csv

# %%
# !head cap-2019-france-utf8.csv | column -s";" -t
# Out:
# Nom / Raison sociale   Commune   Code postal   Libellé rubrique                                  Montant rubrique
# XXX                   XXX       01XXX         III.7 - Aide dans le secteur de l'apiculture      460,00
# XXX                   XXX       01XXX         III.7 - Aide dans le secteur de l'apiculture      796,00
# XXX                   XXX       01XXX         III.7 - Aide dans le secteur de l'apiculture      1000,00
# XXX                   XXX       01XXX         II.1 - Aide de base découplée à la surface (DPB)  246,83
# XXX                   XXX       01XXX         II.1 - Aide de base découplée à la surface (DPB)  467,72
# XXX                   XXX       01XXX         II.1 - Aide de base découplée à la surface (DPB)  222,65
# XXX                   XXX       01XXX         II.1 - Aide de base découplée à la surface (DPB)  535,70
# XXX                   XXX       01XXX         II.1 - Aide de base découplée à la surface (DPB)  232,10
# XXX                   XXX       01XXX         II.1 - Aide de base découplée à la surface (DPB)  407,21

# %%
print('Nombre de lignes :')
# !wc -l cap-2019-france-utf8.csv
# Out:
# Nombre de lignes :
#  1728447 cap-2019-france-utf8.csv

# %%
print('Nombre de colonnes :')
# !head -n 1 cap-2019-france-utf8.csv | sed 's/[^;]//g' | wc -c
# Out:
# Nombre de colonnes :
#        5

# %% [markdown]
# ## Génération du dataframe

# %%
import pandas as pd

# %%
noms_colonnes = ['nom', 'commune', 'codepostal', 'mesure', 'montant']
dtypes_colonnes = {'nom': 'object', 'commune': 'object', 'codepostal': 'object', 'mesure': 'object', 'montant': 'float64'}
df = pd.read_csv('cap-2019-france-utf8.csv', sep=';', encoding='utf-8', header=0, decimal=',', names=noms_colonnes, dtype=dtypes_colonnes)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1728446 entries, 0 to 1728445
# Data columns (total 5 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   nom         object
#  1   commune     object
#  2   codepostal  object
#  3   mesure      object
#  4   montant     float64
# dtypes: float64(1), object(4)
# memory usage: 65.9+ MB

# %%
df.head()
# Out:
#    nom commune codepostal                                            mesure  \
# 0  XXX     XXX      01XXX      III.7 - Aide dans le secteur de l'apiculture
# 1  XXX     XXX      01XXX      III.7 - Aide dans le secteur de l'apiculture
# 2  XXX     XXX      01XXX      III.7 - Aide dans le secteur de l'apiculture
# 3  XXX     XXX      01XXX  II.1 - Aide de base découplée à la surface (DPB)
# 4  XXX     XXX      01XXX  II.1 - Aide de base découplée à la surface (DPB)
#
#    montant
# 0   460.00
# 1   796.00
# 2  1000.00
# 3   246.83
# 4   467.72

# %%
df.describe(include='all')
# Out:
#             nom  commune codepostal  \
# count   1728446  1728446    1728446
# unique   291340    34774       6300
# top         XXX      XXX      64120
# freq     111748    89664       3996
# mean        NaN      NaN        NaN
# std         NaN      NaN        NaN
# min         NaN      NaN        NaN
# 25%         NaN      NaN        NaN
# 50%         NaN      NaN        NaN
# 75%         NaN      NaN        NaN
# max         NaN      NaN        NaN
#
#                                                    mesure       montant
# count                                             1728446  1.728446e+06
# unique                                                 33           NaN
# top     II.3 - Soutien supplémentaire aux premiers hec...           NaN
# freq                                               312365           NaN
# mean                                                  NaN  5.946062e+03
# std                                                   NaN  5.857273e+04
# min                                                   NaN -4.608901e+07
# 25%                                                   NaN  5.227125e+02
# 50%                                                   NaN  2.493570e+03
# 75%                                                   NaN  7.367752e+03
# max                                                   NaN  3.091400e+07

# %% [markdown]
# On observe un grand nombre de valeurs "XXX" dans les colonnes "nom" et "commune". Ceci devrait correspondre aux "petits" bénéficiaires, qui apparaissent de façon anonyme lorsque les montants totaux perçus sont inférieurs ou égaux à 1 250 euros, ainsi qu'aux communes qui comptent moins de 11 bénéficiaires ainsi anonymisés – seul le numéro de département est alors indiqué.

# %%
df[(df['nom'] == 'XXX') & (df['montant'] > 1250)]
# Out:
#          nom               commune codepostal  \
# 4761     XXX  BOHAS-MEYRIAT-RIGNAT      01250
# 33857    XXX                   XXX      03XXX
# 79533    XXX                   XXX      07XXX
# 79971    XXX                   XXX      07XXX
# 106505   XXX                   XXX      09XXX
# ...      ...                   ...        ...
# 1713571  XXX            LE VAUCLIN      97280
# 1722391  XXX              ST ANDRE      97440
# 1725143  XXX             ST JOSEPH      97480
# 1725452  XXX               KOUNGOU      97600
# 1725821  XXX             CHIRONGUI      97620
#
#                                                     mesure  montant
# 4761             III.5 - Soutien au secteur vitivinicole    1838.44
# 33857    II.3 - Soutien supplémentaire aux premiers hec...  1860.89
# 79533            III.5 - Soutien au secteur vitivinicole    3139.41
# 79971           IV/A.16 - Aides à l'agriculture biologique  2862.00
# 106505    II.1 - Aide de base découplée à la surface (DPB)  1990.32
# ...                                                    ...      ...
# 1713571                               VI/C.1 - Aides POSEI  1750.00
# 1722391                               VI/C.1 - Aides POSEI  1258.00
# 1725143                               VI/C.1 - Aides POSEI  1500.00
# 1725452                               VI/C.1 - Aides POSEI  4180.77
# 1725821                               VI/C.1 - Aides POSEI  5201.16
#
# [244 rows x 5 columns]

# %% [markdown]
# On trouve 244 lignes anonymisées qui correspondent pourtant à des montants totaux supérieurs à 1 250 euros. Ceci peut s'expliquer par un mode de présentation différent des données polonaises, puisque premièrement, chaque ligne correspond à un paiement et non à un bénéficiaire (un bénéficiaire peut donc apparaître sur plusieurs lignes), et deuxièmement, sont aussi affichées des opérations comptables comme des remboursements de trop perçus.

# %%
df[(df['commune'] == 'XXX') & (df['codepostal'].str.contains('XX') == False)]
# Out:
# Empty DataFrame
# Columns: [nom, commune, codepostal, mesure, montant]
# Index: []

# %% [markdown]
# Les communes "XXX" sont effectivement associées à des codes postaux en partie effacés pour ne laisser apparaître que le numéro de département.

# %%
n_total_paiements = df.shape[0]
n_total_paiements_horsremb = df[df['montant'] >= 0].shape[0]
somme_paiements_horsremb = df.loc[(df['montant'] >= 0), 'montant'].sum()
solde_net_paiements = df['montant'].sum()
print('Nombre total de paiements :', f'{n_total_paiements:,}')
print('Nombre total de paiements hors remboursements d\'indus par les bénéficiaires :', f"{n_total_paiements_horsremb:,}")
print("Somme des paiements versés à l'ensemble des bénéficiaires hors remboursements d\'indus par les bénéficiaires :", f"{somme_paiements_horsremb.round(2):,}", "euros")
print("Solde net des paiements versés à l'ensemble des bénéficiaires après remboursements d\'indus par les bénéficiaires :", f"{solde_net_paiements.round(2):,}", "euros")
# Out:
# Nombre total de paiements : 1,728,446
# Nombre total de paiements hors remboursements d'indus par les bénéficiaires : 1,684,472
# Somme des paiements versés à l'ensemble des bénéficiaires hors remboursements d'indus par les bénéficiaires : 10,405,023,380.66 euros
# Solde net des paiements versés à l'ensemble des bénéficiaires après remboursements d'indus par les bénéficiaires : 10,277,447,718.46 euros

# %%
n_total_paiements_petits = df[(df['nom'] == 'XXX') & (df['montant'] >= 0)].shape[0]
somme_paiements_petits = df.loc[(df['nom'] == 'XXX') & (df['montant'] >= 0), 'montant'].sum()
print('Nombre de paiements versés à des "petits" bénéficiaires :', f"{n_total_paiements_petits:,}")
print('Somme des paiements versés à des petits bénéficiaires :', f"{somme_paiements_petits:,}", "\n")
print('Nombre de paiements versés à des "petits" bénéficiaires en proportion du total :', n_total_paiements_petits / n_total_paiements_horsremb)
print('Somme des paiements versés à des "petits" bénéficiaires  en proportion du total :', somme_paiements_petits / somme_paiements_horsremb)
# Out:
# Nombre de paiements versés à des "petits" bénéficiaires : 107,052
# Somme des paiements versés à des petits bénéficiaires : 29,430,173.37
#
# Nombre de paiements versés à des "petits" bénéficiaires en proportion du total : 0.06355225851186604
# Somme des paiements versés à des "petits" bénéficiaires  en proportion du total : 0.0028284581680712386

# %% [markdown]
# À la différence de la Pologne, où les petits bénéficiaires anonymes représentent 46% de l'ensemble des bénéficiaires et 8% du montant total des paiements, de tels paiements ne représentent en France que 6% de l'ensemble des paiements et moins de 0.01% de leur valeur totale.

# %%
print('Top 20 des paiements les plus élevés en France')
df.sort_values(by='montant', ascending=False).head(20)
# Out:
# Top 20 des paiements les plus élevés en France
#                                             nom                  commune  \
# 1722744              SAS SUCRIERE DE LA REUNION              STE SUZANNE
# 542159                                  CERAFEL  SAINT-MARTIN-DES-CHAMPS
# 1722763                  SUCRERIE DE BOIS ROUGE              STE SUZANNE
# 1723687                                 URCOOPA         SAINT PAUL CEDEX
# 1709054                               SA GARDEL                 LE MOULE
# 538388        COOPERATIVE MARAICHERE DE L'OUEST       PLOUGASTEL-DAOULAS
# 1714830                                  ARIBEV        SAINT DENIS CEDEX
# 1648269       AGENCE DE SERVICES ET DE PAIEMENT                  LIMOGES
# 1703048       CONSEIL REGIONAL DE LA GUADELOUPE              BASSE TERRE
# 1456247   CENTRE NAT INTERPRO ECONOMIE LAITIERE                  PARIS 9
# 624813     CONSEIL INTERPROF DU VIN DE BORDEAUX                 BORDEAUX
# 830568                                   OCEANE           LA CHEVROLIERE
# 206238                                   AGRIAL                     CAEN
# 1706020                                     GMA             BAIE-MAHAULT
# 627746   UNION COOPERATIVES VINICOLES AQUITAINE                  COUTRAS
# 1715045                                   CIRAD                ST PIERRE
# 1712576                        PETIT MORNE SARL                 LAMENTIN
# 1706722                          SA BOIS DEBOUT     CAPESTERRE BELLE EAU
# 1714831                                    ARIV        SAINT DENIS CEDEX
# 558415                                 GRAP'SUD        CRUVIERS-LASCOURS
#
#         codepostal                                             mesure  \
# 1722744      97441                               VI/C.1 - Aides POSEI
# 542159       29600  III.4 - Aide dans le secteur des fruits et lég...
# 1722763      97441                               VI/C.1 - Aides POSEI
# 1723687      97460                               VI/C.1 - Aides POSEI
# 1709054      97160                               VI/C.1 - Aides POSEI
# 538388       29470  III.4 - Aide dans le secteur des fruits et lég...
# 1714830      97404                               VI/C.1 - Aides POSEI
# 1648269      87000                     IV/A.25 - Assistance technique
# 1703048      97100     IV/A.4 - Soutien aux investissements physiques
# 1456247      75009  VI/A.1 - Soutien actions information et promot...
# 624813       33000          III.5 - Soutien au secteur vitivinicole
# 830568       44118  III.4 - Aide dans le secteur des fruits et lég...
# 206238       14000  III.4 - Aide dans le secteur des fruits et lég...
# 1706020      97122                               VI/C.1 - Aides POSEI
# 627746       33230          III.5 - Soutien au secteur vitivinicole
# 1715045      97410              IV/A.21 - Soutien pour la coopération
# 1712576      97232                               VI/C.1 - Aides POSEI
# 1706722      97130                               VI/C.1 - Aides POSEI
# 1714831      97404                               VI/C.1 - Aides POSEI
# 558415       30360          III.5 - Soutien au secteur vitivinicole
#
#              montant
# 1722744  30914000.00
# 542159   19210952.51
# 1722763  13249000.00
# 1723687  12571910.09
# 1709054  12028545.49
# 538388    6687179.41
# 1714830   6617189.95
# 1648269   6114866.57
# 1703048   5718442.44
# 1456247   5678224.78
# 624813    5470744.24
# 830568    5459179.13
# 206238    5170539.62
# 1706020   4947773.68
# 627746    4786044.31
# 1715045   4560923.10
# 1712576   4181880.04
# 1706722   4167222.11
# 1714831   4024488.49
# 558415    3910305.97

# %% [markdown]
# Compte tenu de la faible proportion des paiements allant aux "petits" bénéficiaires anonymisés, nous allons les écarter de la suite de l'analyse afin de pouvoir regrouper les paiements par bénéficiaire unique. Nous allons aussi écarter les remboursements d'indu qui, en plus de représenter une part limitée de l'ensemble des paiements, se réfèrent en réalité à la précédente campagne de paiement.

# %%
df_reduit = df[(df['nom'] != 'XXX') & (df['montant'] >= 0)].copy()

# %%
grouped = df_reduit.groupby(by=['nom', 'commune','codepostal'])
print('Nombre total de bénéficiaires uniques en France, hors "petits" :', len(grouped.groups))
# Out:
# Nombre total de bénéficiaires uniques en France, hors "petits" : 324150

# %%
print('Top 20 des plus grands bénéficiaires en France')
grouped.sum().sort_values(by='montant', ascending=False).head(20)
# Out:
# Top 20 des plus grands bénéficiaires en France
#                                                                                montant
# nom                                    commune                 codepostal
# SAS SUCRIERE DE LA REUNION             STE SUZANNE             97441       30914000.00
# CERAFEL                                SAINT-MARTIN-DES-CHAMPS 29600       19210952.51
# SUCRERIE DE BOIS ROUGE                 STE SUZANNE             97441       13249000.00
# URCOOPA                                SAINT PAUL CEDEX        97460       12571910.09
# SA GARDEL                              LE MOULE                97160       12028545.49
# CENTRE NAT INTERPRO ECONOMIE LAITIERE  PARIS 9                 75009        6861786.34
# COOPERATIVE MARAICHERE DE L'OUEST      PLOUGASTEL-DAOULAS      29470        6687179.41
# ARIBEV                                 SAINT DENIS CEDEX       97404        6617189.95
# AGENCE DE SERVICES ET DE PAIEMENT      LIMOGES                 87000        6114866.57
# CONSEIL REGIONAL DE LA GUADELOUPE      BASSE TERRE             97100        5718442.44
# CONSEIL INTERPROF DU VIN DE BORDEAUX   BORDEAUX                33000        5470744.24
# OCEANE                                 LA CHEVROLIERE          44118        5459179.13
# AGRIAL                                 CAEN                    14000        5176713.02
# GMA                                    BAIE-MAHAULT            97122        4947773.68
# UNION COOPERATIVES VINICOLES AQUITAINE COUTRAS                 33230        4786044.31
# CIRAD                                  ST PIERRE               97410        4564019.39
# SA BOIS DEBOUT                         CAPESTERRE BELLE EAU    97130        4410515.57
# PETIT MORNE SARL                       LAMENTIN                97232        4240398.36
# ARIV                                   SAINT DENIS CEDEX       97404        4024488.49
# GRAP'SUD                               CRUVIERS-LASCOURS       30360        3910305.97

# %% [markdown]
# Comme dans le cas polonais, un classement "brut" des plus grands bénéficiaires montre qu'un certain nombre d'entre eux sont des institutions publiques qui reçoivent des fonds de la PAC au titre de l'assistance technique ou du développement rural.

# %%
print('Liste des "millionnaires" de la PAC en France')
pd.set_option('display.max_rows', 200)
grouped.sum().loc[lambda x: x['montant'] >= 1000000].sort_values(by='montant', ascending=False)
# Out:
# Liste des "millionnaires" de la PAC en France
#                                                                                                 montant
# nom                                                commune                      codepostal
# SAS SUCRIERE DE LA REUNION                         STE SUZANNE                  97441       30914000.00
# CERAFEL                                            SAINT-MARTIN-DES-CHAMPS      29600       19210952.51
# SUCRERIE DE BOIS ROUGE                             STE SUZANNE                  97441       13249000.00
# URCOOPA                                            SAINT PAUL CEDEX             97460       12571910.09
# SA GARDEL                                          LE MOULE                     97160       12028545.49
# CENTRE NAT INTERPRO ECONOMIE LAITIERE              PARIS 9                      75009        6861786.34
# COOPERATIVE MARAICHERE DE L'OUEST                  PLOUGASTEL-DAOULAS           29470        6687179.41
# ARIBEV                                             SAINT DENIS CEDEX            97404        6617189.95
# AGENCE DE SERVICES ET DE PAIEMENT                  LIMOGES                      87000        6114866.57
# CONSEIL REGIONAL DE LA GUADELOUPE                  BASSE TERRE                  97100        5718442.44
# CONSEIL INTERPROF DU VIN DE BORDEAUX               BORDEAUX                     33000        5470744.24
# OCEANE                                             LA CHEVROLIERE               44118        5459179.13
# AGRIAL                                             CAEN                         14000        5176713.02
# GMA                                                BAIE-MAHAULT                 97122        4947773.68
# UNION COOPERATIVES VINICOLES AQUITAINE             COUTRAS                      33230        4786044.31
# CIRAD                                              ST PIERRE                    97410        4564019.39
# SA BOIS DEBOUT                                     CAPESTERRE BELLE EAU         97130        4410515.57
# PETIT MORNE SARL                                   LAMENTIN                     97232        4240398.36
# ARIV                                               SAINT DENIS CEDEX            97404        4024488.49
# GRAP'SUD                                           CRUVIERS-LASCOURS            30360        3910305.97
# LES VERGERS DE BLUE WHALE                          MONTAUBAN                    82000        3749220.08
# DEPARTEMENT DE LA REUNION                          ST DENIS                     97400        3604065.84
# CHAMBRE D AGRICULTURE                              ST DENIS                     97400        3540913.00
# COMMUNE DU TAMPON                                  LE TAMPON                    97430        3397247.56
# G H MUMM ET CIE                                    REIMS CEDEX                  51100        2985992.09
# SOCIETE PARDI                                      ST ANDIOL                    13670        2786664.60
# SOC CIVILE CHATEAU LEOVILLE LAS CASES              SAINT-JULIEN-BEYCHEVELLE     33250        2727192.67
# NANTEUROP                                          ST JULIEN DE CONCELLES       44450        2720706.24
# ETS PUB IC OFFICE NATIONAL DES FORETS -            CAYENNE                      97307        2700523.68
# AZUR DISTILLATION                                  MAUBEC                       84660        2522051.21
# CHAMPAGNE PERRIER-JOUET                            EPERNAY CEDEX                51200        2503921.33
# DISTILLERIE JEAN GOYARD                            AY-CHAMPAGNE                 51160        2417644.31
# SAS ARDO                                           GOURIN                       56110        2400000.00
# SCOP LES VERGERS D'ANJOU                           VERRIERES EN ANJOU           49481        2399535.10
# STE NOM CO LACTALIS INVESTISSEMENTS                LAVAL                        53000        2350000.00
# LES 3 MOULINS - VITAPRIM                           SAINT-PHILBERT-DE-GRAND-LIEU 44310        2274214.91
# CONSEIL DEPARTEMENTAL DE MAYOTTE                   MAMOUDZOU                    97600        2269707.92
# SARL LA RICHARD                                    LA TRINITE                   97220        2218624.19
# DISTILLERIE DU BEAUJOLAIS                          CHARENTAY                    69220        2187252.46
# NOUVELLE CITE SAS                                  SAINTE-MARIE                 97230        2151569.16
# SARL BAGATELLE                                     GROS MORNE                   97213        2128584.70
# CECAB CENTRALE COOP AGRIC BRET                     THEIX-NOYALO                 56450        2082627.14
# ASSOCIATION SYNDICALE D'IRRIGATION DE L'           VILLARS LES DOMBES           01330        2077544.95
# SOC COOPERATIVE AGRICOLE VALPRIM                   MARMANDE                     47200        2075521.16
# SARL TI FONDS                                      LE FRANCOIS                  97240        2062678.90
# SOCIETE AGRICOLE DE BOLOGNE                        BASSE TERRE                  97100        2060707.55
# SOCIETE DE DISTILLERIES VINICOLES DU BLAYAIS       VAL-DE-LIVENNE               33860        2048225.52
# SAS EUROSERUM                                      PORT SUR SAONE               70170        1994941.26
# EDEN SARL                                          AJOUPA BOUILLON              97216        1994468.94
# MARCHE DE PHALEMPIN                                PHALEMPIN                    59133        1985469.71
# SA DES SUCRERIES ET RHUMERIES DE MARIE GALANTE     GRAND BOURG DE MARIE-GALANTE 97112        1942454.51
# PETITE GRENADE SARL                                LAMENTIN                     97280        1890857.10
# MNA                                                LAMENTIN                     97232        1873847.30
# SARL UNION                                         LE LAMENTIN                  97232        1860201.75
# TERRENA                                            ANCENIS-SAINT-GEREON         44150        1830204.44
# CAFEIERE SAS                                       SAINT-JOSEPH                 97230        1803502.21
# PECOUL SAS                                         BASSE POINTE                 97218        1800450.23
# SAS DISTILLERIE DOUENCE                            SAINT-GENES-DE-LOMBAUD       33670        1779387.62
# SAS AGRISUD                                        PERPIGNAN                    66000        1778735.08
# SA BAMARYL                                         LE FRANCOIS                  97240        1772965.39
# CRASSOUS AGRICOLE SAS                              MACOUBA                      97218        1755242.12
# COOP SOLARENN                                      ST ARMEL                     35230        1749852.91
# MADIVIAL                                           LAMENTIN                     97232        1730050.15
# CAVE DE SAUVETERRE BLASIMON ESPIET                 SAUVETERRE-DE-GUYENNE        33540        1710746.23
# LE MOULIN                                          LE ROBERT                    97231        1673011.77
# ASS ORGA. PRODUCTEURS LEGUMES INDUSTRIE            ESTREES-MONS                 80200        1666381.13
# ASSOCIATION ARMEFLHOR                              ST PIERRE                    97410        1661525.32
# CAPOTE SARL                                        BASSE POINTE                 97218        1659796.51
# SARL RIVIERE LEZARDE                               ST JOSEPH                    97212        1659788.11
# SARL HABITATION TRIANON                            LE LAMENTIN                  97232        1655521.33
# COMMUNE D'APATOU                                   APATOU                       97317        1637118.63
# DUHAUMONT SARL                                     MARIGOT                      97225        1623889.67
# BELLEVUE SARL                                      SAINTE MARIE                 97230        1623366.79
# SARL HABITATION LE VERGER                          BASSE POINTE                 97218        1592301.87
# JARDIN CLEMENT SARL                                BASSE POINTE                 97218        1584107.57
# BAN HACKAERT SARL                                  BASSE POINTE                 97218        1582460.05
# BOYER                                              MOISSAC                      82200        1576021.92
# EYMA SARL                                          BASSE POINTE                 97218        1575815.52
# SARL BANANERAIE SAINT-JULIEN                       CAPESTERRE BELLE EAU         97130        1571772.12
# ASSOCIATION FIL ROUGE                              PARIS 12                     75012        1569521.30
# SIBAN EURL                                         FRANCOIS                     97240        1565651.18
# GRADIS SARL                                        BASSE POINTE                 97218        1540840.36
# DUPOTICHE SARL                                     MACOUBA                      97218        1537326.40
# SARL MACOUBA                                       BASSE POINTE                 97218        1530605.75
# TAITTINGER COMPAGNIE COMMERCIALE ET VITICOLE CH... REIMS                        51100        1525969.50
# MOULIN L'ETANG SARL                                BASSE POINTE                 97218        1519865.80
# IGUAVIE                                            BAIE MAHAULT                 97122        1516097.28
# SARL HORTI-FRUITS                                  LE MARIGOT                   97225        1484471.94
# ASSOCIATION GDS REUNION                            LE TAMPON                    97418        1431261.12
# POM'EVASION                                        LES GARENNES SUR LOIRE       49610        1427705.07
# CS DE CIZE                                         ST JEAN PIED DE PORT         64220        1425637.16
# SARL HABITATION GRAND SUD                          LE VAUCLIN                   97280        1422830.85
# BOCHET SARL                                        LAMENTIN                     97232        1421325.58
# FRANCE CHAMPIGNON                                  SAUMUR                       49400        1419040.20
# UNION DISTILLERIES MEDITERRANEE                    VALLON PONT D'ARC            07150        1410921.68
# SAS SOCIETE JEAN FLOC'H                            BAUD                         56150        1410439.01
# COLLECTIVITE TERRITORIALE DE MARTINIQUE            FORT DE FRANCE               97261        1410010.26
# DOMAINES BARONS DE ROTHSCHILD LAFITE DIS           BORDEAUX                     33300        1409452.46
# SNPC SARL                                          SAINTE-MARIE                 97230        1398145.88
# SA BERNARD ABATTOIRS                               MOREAC                       56500        1380377.45
# NATUR'COOP                                         BOURSIES                     59400        1364825.62
# SCA APPROVISIONNEMENT DES AVIRONS                  LES AVIRONS                  97425        1361297.14
# UNION DISTILLERIES MEDITERRANEE                    VAUVERT                      30600        1357001.77
# EPCI COMMUNAUTE DE COMMUNES DE L'OUEST G           MANA                         97360        1351508.34
# UNION DISTILLERIES MEDITERRANEE                    OLONZAC                      34210        1345667.53
# COGEDAL                                            SAINT PIERRE CEDEX           97455        1336900.93
# SOC COOP AGR PRIMACOOP                             SOYECOURT                    80200        1327796.00
# SCA FRUITS ET LEGUMES DU LIMOUSIN LIMDOR           ST YRIEIX LA PERCHE          87500        1325343.42
# SARL EXPLOITATION PLAINE DU GALION                 LA TRINITE                   97220        1322863.00
# TRISKALIA                                          LANDERNEAU                   29800        1311071.93
# SAS EURIAL ULTRA FRAIS                             CHATEAU SALINS               57170        1310731.48
# STE CIVILE VINICOLE CHATEAU DU TARIQUET            EAUZE                        32800        1302017.30
# EKWALI EX SOMADEV                                  DEMBENI                      97660        1298715.56
# SARL BANANES DU MALGRE TOUT                        LA TRINITE                   97220        1297848.91
# SOCIETE COOPERATIVE AGRICOLE FRANCE PRUNE          CASSENEUIL                   47440        1289203.67
# SCICA ALTUS                                        YCHOUX                       40160        1284757.73
# SASU COTOTERRA                                     REMOUILLE                    44140        1280000.00
# SAS OVOMA                                          DEMBENI                      97660        1276901.86
# SCA UNICOQUE                                       CANCON                       47290        1273886.73
# ASSIER SARL                                        LORRAIN                      97214        1266901.42
# OP LES CIMES                                       LES MEES                     04190        1264306.99
# ASSOCIATION ASCO DU CANAL DE L'ISLE                L ISLE SUR LA SORGUE         84800        1263722.03
# SARL EXPL AGRICOLE SUD-EST                         LE FRANCOIS                  97240        1251034.20
# CAPEXO                                             CHEVILLY-LARUE               94550        1244097.56
# SOCIETE RHUM DAMOISEAU                             LE MOULE                     97160        1242809.42
# OP-L-VERT                                          ESTREES-MONS                 80200        1236332.00
# DISTILLERIE BEL                                    SAINT-THIBERY                34630        1233509.33
# SA PROCANAR                                        LAUZACH                      56190        1232766.12
# EXPLOITATION DE BANANES DU GALION SARL             TRINITE                      97220        1230977.94
# SARL SOCIETE AGRICOLE PERINELLE                    ST PIERRE                    97250        1228575.97
# SAS DISTRIBUTION DU DOMAINE D'UBY                  CAZAUBON                     32150        1224771.70
# PAQUEMAR SARL                                      VAUCLIN                      97280        1218146.87
# SARL CITEFI                                        LE FRANCOIS                  97240        1217246.07
# CTG - CELLULE DE GESTION DES FONDS EUROP           CAYENNE                      97300        1212475.02
# SAS LES JUS DE MARMANDE                            MARMANDE                     47200        1200000.00
# SAS DEUERER PETCARE FRANCE                         VILLENEUVE SUR LOT           47300        1200000.00
# SCEA DE LA GIRAUDIERE                              BASSE GOULAINE               44115        1199999.99
# DISTILLERIE DE DORDOGNE                            SAINT-LAURENT-DES-VIGNES     24100        1195029.88
# SAS AVIMA                                          MAMOUDZOU                    97600        1191543.29
# SARL SEA CHANGY-DAMBAS                             ST CLAUDE                    97120        1185924.77
# GIE GIE ERCANE - EX GIE CERF                       ST DENIS                     97494        1174250.00
# ASSOCIATION DEVELOPPEMENT RURAL REUNION            ST DENIS                     97490        1168651.08
# COMMUNE MAIRIE DE BANDRELE                         BANDRELE                     97660        1155287.48
# COMMUNE DE SAINT-PAUL                              ST PAUL                      97861        1152262.87
# COMMUNAUTE D'AGGLOMERATION TULLE AGGLO             TULLE                        19000        1143241.36
# COOP ALLIANCE FORETS BOIS                          CESTAS                       33610        1134771.30
# GROUP PRODUCTEURS LEGUMES DE LA MANCHE             CREANCES                     50710        1131115.91
# SAS MINOTERIES DU CHATEAU                          ERNEE                        53500        1120000.00
# SAS MECHINAUD                                      REZE                         44400        1120000.00
# COOPERATIVE FRUITS ET LEGUMES DES PO - T           ST HIPPOLYTE                 66510        1115967.74
# LES GRANDS CHAIS DE FRANCE                         PETERSBACH                   67290        1106385.06
# SCA FRUITS DE LA REUNION                           ST LOUIS                     97450        1084875.47
# SCEA LES HAUTS DE CAMBREFORTS                      CAPESTERRE B-EAU             97130        1084138.67
# SCL DU BEAUFORTAIN                                 BEAUFORT                     73270        1072756.00
# SAEM DE PRODUCTION SUCRIERE ET RHUMIERE DE LA M... TRINITE                      97220        1066000.00
# MALLENEC PHILIPPE GERARD LOUIS                     BAIE-MAHAULT                 97191        1061542.32
# SA ADRIEN BELLIER                                  ST ANDRE                     97440        1047638.91
# GIE LES COTEAUX                                    GENERAC                      30510        1018112.55
# CAVES DE RAUZAN DITES GRANGENEUVE OU LE NOBLE O... RAUZAN                       33420        1016088.10
# SARL VALLEE DU LORRAIN                             LE MARIGOT                   97225        1006290.06
# SAS OTIMO                                          BREBIERES                    62117        1000000.00

# %% [markdown]
# Plus largement, parmi les "millionnaires" de la PAC, on trouve un grand nombre d'entités publiques ou privées situées dans des départements d'outre-mer et identifiés par un code postal commençant par 97.

# %%
print('Distribution des bénéficiaires uniques en fonction du montant total des subventions reçues')
pd.set_option('display.float_format', '{:.2f}'.format)
grouped.sum().describe(percentiles=[.1, .2, .3, .4, .5, .6, .7, .8, .9], include=[float])
# Out:
# Distribution des bénéficiaires uniques en fonction du montant total des subventions reçues
#           montant
# count   324150.00
# mean     32008.62
# std      96894.85
# min       1250.03
# 10%       3103.90
# 20%       6564.82
# 30%      11530.32
# 40%      16907.73
# 50%      22531.99
# 60%      28794.70
# 70%      36215.57
# 80%      46347.26
# 90%      65439.00
# max   30914000.00

# %% [markdown]
# Les "millionnaires" français de la PAC sont néanmoins très minoritaires : ils ne sont que 161 alors que 90% des bénéficiaires reçoivent moins de 65 439 euros (neuvième décile).
